# %%
import os, os.path
import pandas as pd

def getData(DIR):
    solutions = dict()

    for name in os.listdir(DIR):
        if(name != '.gitkeep'):
            # get key for the dictionary
            parts = name.split('.')
            if(not parts[0] in solutions.keys()):
                solutions[parts[0]] = list()
            # get data
            name = f'{DIR}/{name}'
            data = pd.read_csv(name, sep=" ", header=None)
            data.columns = ["solution"]
            solutions[parts[0]].append((parts[1], data))
    return solutions

solutionsOne = getData('./output/test.one')
print(solutionsOne.keys())
# Out:
# dict_keys(['NL10', 'NL16', 'NL14', 'NL6', 'NL12', 'NL4'])

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import numpy as np

def plotData(solutions, typeSwap, names):
    colors = ['red', 'green', 'blue', 'orange', 'pink', 'black']
    for arch in ['NL4', 'NL6', 'NL10', 'NL12', 'NL14', 'NL16']:
        mini = float('inf')
        for swapType, data in solutions[arch]:
            # select color
            for i in range(len(names)):
                if(swapType == names[i]):
                    color = colors[i]
            plt.plot(data[0:50], color=color)
            miniIteration = np.min(data[0:50])
            if(int(miniIteration) < mini):
                mini = int(miniIteration)
                swap = swapType
        # options for the plot
        plt.title(arch)
        colors_list = [ mpatches.Patch(color=colors[i], label=names[i]) for i in range(len(names))]
        plt.legend(handles=colors_list)
        plt.xlabel('Iteraciones')
        plt.ylabel('Resultado Función Objetivo')
        print(mini, swap)
        plt.savefig(f'./img/{arch}.{typeSwap}.jpg')
        plt.show()

# %%
plotData(solutionsOne, 'one', ['swaphomes', 'swapmatches', 'swaprounds', 'swapteams'])
# Out:
# 8276 swapteams
# 26191 swaprounds
# 71629 swaprounds
# 139050 swapmatches
# 252551 swapteams
# 350403 swaprounds

# %%
solutionsTwo = getData('./output/test.two')
plotData(solutionsTwo, 'two', ['swaphomesandmatches', 'swaphomesandrounds', 'swapmatchesandrounds', 'swaphomesandteams', 'swaproundsandteams', 'swapmatchesandrounds'])
# Out:
# 8276 swaphomesandteams
# 24982 swaphomesandrounds
# 68943 swaphomesandrounds
# 132338 swaphomesandteams
# 233071 swaphomesandteams
# 315834 swaphomesandteams

# %%
solutionsFinal = getData('./output/test.final')
plotData(solutionsFinal, 'three', ['swapThree', 'swapThree2'])
# Out:
# 8276 swapThree2
# 25609 swapThree
# 70052 swapThree
# 130686 swapThree
# 244089 swapThree
# 355196 swapThree

# %%
solutionsResultado = getData('./output/resultados')

# %%
for segment in solutionsResultado.keys():
    print(segment)
    dictMin = dict()
    for result in solutionsResultado[segment]:
        weigth, values = result
        if(not weigth in dictMin.keys()):
            dictMin[weigth] = 0
        minimo = int(np.min(values))
        dictMin[weigth] += minimo
    print(dictMin)
# Out:
# Super4
# {'22500': 634534}
# galaxy16
# {'1200': 184287}
# NL14
# {'22500': 2373526}
# NL10
# {'22500': 686652}
# galaxy18
# {'1200': 262672}
# galaxy6
# {'1200': 13243}
# galaxy12
# {'1200': 87721}
# galaxy20
# {'1200': 473298}
# galaxy10
# {'1200': 52305}
# Super10
# {'22500': 3862131}
# galaxy14
# {'1200': 132384}
# NL4
# {'22500': 83056}
# Super6
# {'22500': 1247855}
# NL16
# {'22500': 3371502}
# galaxy4
# {'1200': 4165}
# NL12
# {'22500': 1332279}
# NL6
# {'22500': 226758}
# Super8
# {'22500': 2374743}
# galaxy8
# {'1200': 26344}
# Super12
# {'22500': 5619495}
# Super14
# {'22500': 7497051}
