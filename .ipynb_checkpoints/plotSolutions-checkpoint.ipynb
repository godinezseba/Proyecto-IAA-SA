# %%
import os, os.path
import pandas as pd

def getData(DIR):
    solutions = dict()

    for name in os.listdir(DIR):
        if(name != '.gitkeep'):
            # get key for the dictionary
            parts = name.split('.')
            if(not parts[0] in solutions.keys()):
                solutions[parts[0]] = list()
            # get data
            name = f'{DIR}/{name}'
            data = pd.read_csv(name, sep=" ", header=None)
            data.columns = ["solution"]
            solutions[parts[0]].append((parts[1], data))
    return solutions

solutionsOne = getData('./output/test.one')
print(solutionsOne.keys())
# Out:
# dict_keys(['NL10', 'NL16', 'NL14', 'NL6', 'NL12', 'NL4'])

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import numpy as np

def plotData(solutions, typeSwap, names):
    for arch in ['NL4', 'NL6', 'NL10', 'NL12', 'NL14', 'NL16']:
        mini = float('inf')
        for swapType, data in solutions[arch]:
            if(swapType == names[0]):
                color = 'red'
            elif(swapType == names[1]):
                color = 'green'
            elif(swapType == names[2]):
                color = 'blue'
            else:
                color = 'orange'
            plt.plot(data[0:50], color=color)
            miniIteration = np.min(data[0:50])
            if(int(miniIteration) < mini):
                mini = int(miniIteration)
                swap = swapType
        # options for the plot
        plt.title(arch)
        red_patch = mpatches.Patch(color='red', label=names[0])
        green_patch = mpatches.Patch(color='green', label=names[1])
        blue_patch = mpatches.Patch(color='blue', label=names[2])
        orange_patch = mpatches.Patch(color='orange', label=names[3])
        plt.legend(handles=[red_patch, green_patch, blue_patch, orange_patch])
        plt.xlabel('Iteraciones')
        plt.ylabel('Resultado Función Objetivo')
        print(mini, swap)
        plt.savefig(f'./img/{arch}.{typeSwap}.jpg')
        plt.show()

# %%
plotData(solutionsOne, 'one', ['swaphomes', 'swapmatches', 'swaprounds', 'swapteams'])
# Out:
# 8276 swapteams
# 26191 swaprounds
# 71629 swaprounds
# 139050 swapmatches
# 252551 swapteams
# 350403 swaprounds

# %%
solutionsTwo = getData('./output/test.two')
plotData(solutionsTwo, 'two', ['swaphomesandmatches', 'swaphomesandrounds', 'swapmatchesandrounds', 'swaphomesandteams', 'swaproundsandteams', 'swapmatchesandrounds'])
# Out:
# 8276 swapmatchesandrounds
# 24982 swaphomesandrounds
# 68943 swaphomesandrounds
# 132503 swaphomesandrounds
# 246619 swaphomesandmatches
# 343075 swapmatchesandrounds

# %%
solutionsFinal = getData('./output/test.final')
for arch in ['NL4', 'NL6', 'NL10', 'NL12', 'NL14', 'NL16']:
    mini = float('inf')
    for swapType, data in solutionsFinal[arch]:
        plt.plot(data[10:50], color='red')
        miniIteration = np.min(data[0:50])
        if(int(miniIteration) < mini):
            mini = int(miniIteration)
    # options for the plot
    plt.title(arch)
    red_patch = mpatches.Patch(color='red', label='swapThree')
    plt.legend(handles=[red_patch])
    plt.xlabel('Iteraciones')
    plt.ylabel('Resultado Función Objetivo')
    print(mini)
    plt.savefig(f'./img/{arch}.three.jpg')
    plt.show()
# Out:
# 8276
# 25609
# 70052
# 130686
# 244089
# 355196

# %%
solutionsResultado = getData('./output/resultados')

# %%
for segment in solutionsResultado.keys():
    print(segment)
    dictMin = dict()
    for result in solutionsResultado[segment]:
        weigth, values = result
        if(not weigth in dictMin.keys()):
            dictMin[weigth] = 0
        minimo = int(np.min(values))
        dictMin[weigth] += minimo
    print(dictMin)
# Out:
# NL16
# {'5000': 3508186, '2500': 3418744, '7500': 3548715}
# NL4
# {'7500': 82973, '2500': 82973, '5000': 82973}
# galaxy10
# {'400': 54137, '1200': 54436, '800': 53652}
# Super14
# {'7500': 8248451, '15000': 8415506, '22500': 8325327}
# Super4
# {'22500': 737698, '15000': 737698, '7500': 737698}
# NL6
# {'2500': 259307, '7500': 257965, '5000': 259151}
# NL14
# {'2500': 2587613, '5000': 2545610, '7500': 2589048}
# Super12
# {'15000': 5987343, '7500': 6007001, '22500': 6174938}
# galaxy16
# {'1200': 195395, '400': 191887, '800': 194773}
# galaxy20
# {'800': 347845, '400': 345626, '1200': 349306}
# NL10
# {'5000': 718712, '7500': 735964, '2500': 715780}
# galaxy4
# {'400': 4226, '800': 4226, '1200': 4226}
# Super8
# {'15000': 2618001, '7500': 2651167, '22500': 2717193}
# galaxy18
# {'1200': 268313, '400': 264968, '800': 267932}
# galaxy6
# {'800': 14702, '400': 14583, '1200': 14702}
# Super6
# {'15000': 1496408, '7500': 1403887, '22500': 1539541}
# galaxy12
# {'1200': 92925, '800': 93237, '400': 92430}
# NL12
# {'5000': 1387541, '7500': 1401530, '2500': 1390452}
# Super10
# {'22500': 3953870, '15000': 3884874, '7500': 3753763}
# galaxy14
# {'400': 141811, '1200': 144076, '800': 143208}
# galaxy8
# {'1200': 29318, '400': 29136, '800': 29272}
